# %% [markdown]
# #Directory Structures and changing directories

# %% [markdown]
# We quickly learned that no one has done much command line programming.  Back in the day.......
# But we need to understand some command line work and how a computer is set up to make our life easier.  We don't need to know much yet.  But we need to know how to move around directories.  when programming I usually find it easier to program in the directory I have things saved and to use relative directories.  This will make sense in a second.  So here are a few lines of code in order to show a directory structure.  Lets look and then practice.....

# %% [markdown]
# The easiest way to avoid directories is to go to the directory you are working in and open your iPython notebook from there.  But sometimes you can't do that. But we can use some linux or dos commands to move around

# %% [markdown]
# If you want to know the path to your current directory type pwd

# %%
pwd
# Out:
# u'C:\\work-teaching\\python\\fall15\\BigDataPython'

# %% [markdown]
# If you want to know what is in your directory type list or ls

# %%
ls  #on a pc you might have to type !dir as you are using dos commands......
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D0AD-C6E1
#
#  Directory of C:\work-teaching\python\fall15\BigDataPython
#
# 08/07/2015  08:30 AM    <DIR>          .
# 08/07/2015  08:30 AM    <DIR>          ..
# 08/07/2015  08:28 AM    <DIR>          .ipynb_checkpoints
# 09/16/2005  09:05 PM           192,305 127_2800.JPG
# 04/15/2015  05:22 PM           169,375 128.png
# 09/16/2005  09:05 PM           216,200 128_2801.JPG
# 01/28/2015  10:32 PM               814 addition.html
# 01/28/2015  06:04 PM               100 addition.txt
# 01/28/2015  10:37 PM               667 addition1.html
# 01/29/2015  10:17 AM               569 addition-1to50.html
# 02/24/2015  10:37 AM            20,280 array-axes.png
# 03/05/2015  04:49 PM           125,016 As-corr.pdf
# 03/05/2015  03:42 PM           125,016 As-corr2.pdf
# 03/05/2015  04:38 PM            66,824 As-corr4.png
# 03/05/2015  04:01 PM            94,685 As-corr-4.png
# 03/05/2015  04:41 PM            94,880 As-corr6.png
# 02/24/2015  03:36 PM             1,380 Brian.csv
# 02/25/2015  06:23 PM            19,070 brianhw.ipynb
# 03/25/2015  10:29 PM           203,178 cartopy-extras.ipynb
# 01/22/2015  06:29 PM         4,093,009 central_park.csv
# 04/15/2015  05:32 PM         1,442,071 china.gif
# 03/23/2015  01:15 PM             1,541 CoreEM09GC01.csv
# 08/04/2015  03:59 PM    <DIR>          directories
# 01/23/2015  05:28 PM           966,364 directory-structure.html
# 08/07/2015  08:30 AM           769,136 directory-structure.ipynb
# 03/24/2015  04:03 PM         5,998,832 EM09-GC-01_comp.jpg
# 03/04/2015  02:59 PM            90,615 enumerate.ipynb
# 02/04/2015  11:09 AM            22,202 equationofline.ipynb
# 02/04/2015  11:07 AM            22,990 equationofline-answer.ipynb
# 03/04/2015  11:00 AM            21,955 filetest3.pdf
# 03/04/2015  11:00 AM           161,754 filetest4.pdf
# 02/12/2015  03:36 PM           116,544 FitALine.ipynb
# 03/19/2015  12:38 PM            64,749 fldav_ljo.csv
# 02/04/2015  12:02 PM            45,647 for-loops.ipynb
# 02/13/2015  04:23 PM             2,180 gdp.csv
# 02/12/2015  04:46 PM             4,841 GDP-Lifespan.csv
# 08/04/2015  04:00 PM    <DIR>          gif
# 03/25/2015  05:39 PM           112,257 globe.jpg
# 02/07/2015  03:13 PM            47,528 ifelif.ipynb
# 01/23/2015  05:28 PM           240,077 intro-to-python-types-print-lists.html
# 01/23/2015  05:41 PM            28,624 intro-to-python-types-print-lists.ipynb
# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D0AD-C6E1
#
#  Directory of C:\work-teaching\python\fall15
#
# 08/04/2015  04:01 PM    <DIR>          .
# 08/04/2015  04:01 PM    <DIR>          ..
# 08/04/2015  03:58 PM    <DIR>          arsenic
# 08/04/2015  03:58 PM    <DIR>          bakker
# 05/18/2015  11:09 AM           272,677 Barnard_-_Lecture-Se_May_18__2015.pdf
# 08/04/2015  03:58 PM    <DIR>          basic-python
# 08/07/2015  08:36 AM    <DIR>          BigDataPython
# 08/04/2015  04:00 PM    <DIR>          BigDataPython-old
# 02/24/2015  04:11 PM            10,849 Brian.png
# 08/04/2015  04:00 PM    <DIR>          central-park
# 10/03/2014  10:13 AM           224,821 code-acadepy-python-part1.pdf
# 06/03/2014  09:48 AM           312,629 computationalpython_ipython.pdf
# 08/04/2015  04:00 PM    <DIR>          grades
# 08/04/2015  04:00 PM    <DIR>          Homeworks
# 08/04/2015  04:00 PM    <DIR>          libby
# 09/19/2014  01:29 PM            90,464 map
# 03/25/2015  10:13 PM             1,248 map addresses for class 2015-40df218c02fc copy.txt
# 09/19/2014  01:29 PM            90,464 map.png
# 08/04/2015  04:00 PM    <DIR>          MathWorksheets
# 09/17/2014  08:25 PM            14,906 myfirstpythonfigure.pdf
# 08/04/2015  04:01 PM    <DIR>          netcdf-old
# 08/04/2015  04:01 PM    <DIR>          New folder
# 01/20/2015  06:04 PM    <DIR>          New folder (2)
# 01/19/2015  12:02 PM            16,859 Python how to.docx
# 06/03/2014  09:48 AM           343,040 Re  python.msg
# 08/04/2015  04:01 PM    <DIR>          shortcourse
# 08/06/2015  11:51 AM    <DIR>          syllabus
# 08/04/2015  04:01 PM    <DIR>          temp-for-print
# 01/29/2015  11:17 AM            17,101 worksheets.ipynb
# 08/04/2015  04:01 PM    <DIR>          worldprecip
#               11 File(s)      1,395,058 bytes
#               19 Dir(s)   6,922,006,528 bytes free

# %% [markdown]
# now you can move down a directory. Tab complete will help you.

# %%
cd BigDataPython/
# Out:
# C:\work-teaching\python\fall15\BigDataPython

# %% [markdown]
# we can move to root

# %%
cd /
# Out:
# C:\

# %% [markdown]
# now we can copy and paste and move all the way back. Having no spaces in you file and folder names makes life simpler

# %%
cd work-teaching\python\fall15\BigDataPython
# Out:
# C:\work-teaching\python\fall15\BigDataPython

# %%
pwd
# Out:
# u'C:\\work-teaching\\python\\fall15\\BigDataPython'

# %% [markdown]
# Now I am going to show a picture below to show you what the directory structure looks like on a mac and then on a pc.  But also look at the code and this is how you add an image using ipython!

# %%
from IPython.display import Image
Image(filename='directories/directory_tree.png')

# %%
Image(filename='directories/folder-structure-home-comp.png')

# %% [markdown]
# Your goal should be to download the photos and then move to the correct directory and open them.  You could also open them with an absolute path! As I did for the python image.  Absolute paths can get you in trouble if you move folders around so i try to keep things with relative paths.

# %%
Image(filename='C:/work-teaching/python/fall15/BigDataPython/directories/python.jpg')

# %% [markdown]
# can you download an image from the web and show it?  Here is a webpage that gives you a lot of information about making ipython notebooks look good! http://nbviewer.ipython.org/github/adrn/ipython/blob/1.x/examples/notebooks/Part%205%20-%20Rich%20Display%20System.ipynb

# %% [markdown]
# You can also make a new directory if you need it with
# mkdir

# %%
mkdir "space space"

# %% [markdown]
# I added the quotes because I had white space in the name. Now that you are coding I would removed white space from names.  It keeps life simple.  Make sure you are comfortable moving around and getting to the usb key.  What images are you going to load?

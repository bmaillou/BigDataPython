# %% [markdown]
# # Pandas Time Series

# %% [markdown]
# Today we are going to look at CO2 data and try to learn about time series.  I will  introduce it and then you will be in charge of analyzing CO2 data from Mauna Lao.  We are going to start by looking at the data from the Scripps Pier.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %% [markdown]
# First go get CO2 data for Scripps.  http://scrippsco2.ucsd.edu/data/ljo and the La Jolla Pier.  I did the daily values.  Open the CSV.  All I did was rename the columns and called the Date, HR, Excel, Year, Flask, Flag, CO2.  Then we can skip the rows and columns we don't want.
#
#
# This is a tough file to read b/c it has a big header.  So we skiprows. But then it has different names.  So what to do???  Lets look at the documentation http://pandas.pydata.org/pandas-docs/dev/generated/pandas.io.parsers.read_csv.html  Then we can also look at some examples.
#
#
# Start by just reading in the data.  do you get the data?  Then get more clever as you go.  Here is the read_csv information.  http://pandas.pydata.org/pandas-docs/dev/generated/pandas.io.parsers.read_csv.html
#
# You just need to try and do to learn.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68)

# %%
print scripps
# Out:
#             Date      Hr     Excel      Year  Flasks  Flags     CO2
# 0     10/23/1968   11:10  25134.47  1968.810       0      4  369.38
# 1     10/31/1968   14:44  25142.61  1968.832       0      4  332.92
# 2      1/13/1969   15:00  25216.62  1969.035       2      0  333.00
# 3      1/17/1969   15:24  25220.64  1969.046       3      0  331.50
# 4      1/20/1969   15:42  25223.65  1969.054       0      4  326.87
# 5      1/29/1969   15:47  25232.66  1969.079       3      0  330.50
# 6      2/18/1969   16:28  25252.69  1969.133       3      0  326.50
# 7      2/21/1969   14:12  25255.59  1969.141       8      0  326.58
# 8       4/1/1969   15:00  25294.62  1969.248       4      0  327.62
# 9      6/18/1969   15:11  25372.63  1969.462       2      0  326.00
# 10     10/2/1969   14:37  25478.61  1969.752       3      0  323.49
# 11    10/23/1969   15:40  25499.65  1969.810       3      0  327.20
# 12     4/14/1970   16:23  25672.68  1970.284       4      0  329.12
# 13     4/27/1970   16:17  25685.68  1970.320       0      4  332.03
# 14     5/11/1970   16:19  25699.68  1970.358       2      0  331.73
# 15     6/17/1970   13:30  25736.56  1970.459       2      0  327.91
# 16     6/29/1970   16:01  25748.67  1970.492       2      0  326.53
# 17     7/17/1970   16:45  25766.70  1970.542       0      4  325.44
# 18     9/14/1970   17:16  25825.72  1970.703       2      0  322.27
# 19    10/12/1970   15:00  25853.62  1970.780       0      4  327.61
# 20    12/21/1970   15:03  25923.63  1970.972       3      0  327.49
# 21     1/25/1971   15:48  25958.66  1971.068       2      5  386.92
# 22     2/17/1971   15:11  25981.63  1971.131       3      0  328.60
# 23     2/22/1971   15:17  25986.64  1971.144       2      0  330.41
# 24     2/25/1971   16:41  25989.70  1971.153       2      0  330.97
# 25      3/1/1971   15:04  25993.63  1971.163       4      0  331.97
# 26      3/5/1971   16:45  25997.70  1971.175       4      5  334.98
# 27     3/25/1971   16:38  26017.69  1971.229       6      0  329.14
# 28      4/7/1971   16:10  26030.67  1971.265       5      0  330.16
# 29     4/14/1971   16:38  26037.69  1971.284       3      0  330.24
# ...          ...     ...       ...       ...     ...    ...     ...
# 1214  11/18/2013   15:49  41596.66  2013.881       6      5  404.77
# 1215   12/6/2013   15:22  41614.64  2013.931       5      0  401.66
# 1216  12/19/2013   15:21  41627.64  2013.966       6      0  398.57
# 1217   1/27/2014   18:03  41666.75  2014.073       6      0  401.85
# 1218    2/3/2014   14:46  41673.62  2014.092       6      0  400.99
# 1219   2/25/2014   17:58  41695.75  2014.153       2      0  402.39
# 1220    3/4/2014   16:37  41702.69  2014.172       6      0  403.47
# 1221   3/18/2014   15:15  41716.64  2014.210       6      0  402.47
# 1222   3/21/2014   16:02  41719.67  2014.218       6      0  404.21
# 1223    4/2/2014   14:27  41731.60  2014.251       6      0  403.17
# 1224   4/22/2014   15:59  41751.67  2014.306       6      0  404.45
# 1225   4/25/2014   17:02  41754.71  2014.314       6      0  403.79
# 1226    5/4/2014   14:22  41763.60  2014.339       6      0  403.98
# 1227   5/20/2014   14:27  41779.60  2014.382       6      0  402.42
# 1228    6/5/2014   15:06  41795.63  2014.426       6      0  400.82
# 1229   6/10/2014   15:07  41800.63  2014.440       6      0  401.80
# 1230   6/23/2014   16:27  41813.69  2014.476       6      0  398.76
# 1231    7/8/2014   17:03  41828.71  2014.517       6      0  397.06
# 1232   7/11/2014   17:33  41831.73  2014.525       6      0  396.80
# 1233   7/22/2014   14:45  41842.61  2014.555       6      0  394.09
# 1234    8/4/2014   16:18  41855.68  2014.591       6      0  392.01
# 1235   8/18/2014   14:19  41869.60  2014.629       6      0  393.51
# 1236    9/2/2014   16:41  41884.70  2014.670       6      0  392.11
# 1237   9/18/2014   15:16  41900.64  2014.714       6      0  394.70
# 1238   10/9/2014   11:45  41921.49  2014.771       6      5  400.09
# 1239  10/15/2014   15:19  41927.64  2014.788       6      0  395.86
# 1240   11/2/2014   14:18  41945.60  2014.837       6      0  401.26
# 1241  11/14/2014   14:28  41957.60  2014.870       6      0  399.85
# 1242  12/13/2014   15:43  41986.65  2014.950       6      0  402.16
# 1243  12/17/2014   17:25  41990.73  2014.961       6      0  401.74
#
# [1244 rows x 7 columns]

# %% [markdown]
# But we only want to the Date, Hr, Flags, and CO2.  So just grab those columns using use_cols

# %% [markdown]
# I just learned a neat trick and the reason why my printouts my look different then yours sometimes.  Sometimes when I print it actually just shows df.info()  which can be useful. so I am going to use this call to get us smaller descriptive outputs.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6])
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1244 entries, 0 to 1243
# Data columns (total 4 columns):
# Date     1244 non-null object
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 48.6+ KB
#  None

# %% [markdown]
# This does the same thing but using column names.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=['Date','Hr','Flags','CO2'])
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1244 entries, 0 to 1243
# Data columns (total 4 columns):
# Date     1244 non-null object
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 48.6+ KB
#  None

# %% [markdown]
# Now lets turn the Date into a datetime index.  It is critical to get a datetime index. I can't stress that enough. So you can make sure it

# %% [markdown]
# #Remember you need a date time index!

# %% [markdown]
# #Remember what I said.  The date time index is critical and can really mess you up if you don't have it!

# %% [markdown]
# First we are making Date the index column

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6],index_col='Date')
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1244 entries, 10/23/1968 to 12/17/2014
# Data columns (total 3 columns):
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 38.9+ KB
# None

# %% [markdown]
# We now have the Dates as an index but we don't have a datetime index. We need that!  parse_dates tells it it is a date

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6],index_col='Date',parse_dates=True)
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 1968-10-23 to 2014-12-17
# Data columns (total 3 columns):
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 38.9+ KB
# None

# %% [markdown]
# #Now we have a datetime index!

# %% [markdown]
# Now we have that.  We could have also

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6],parse_dates='Date',index_col='Date')
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 1968-10-23 to 2014-12-17
# Data columns (total 3 columns):
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 38.9+ KB
#  None

# %% [markdown]
# But you can also just read in and deal with it later.  First we can set the Date to a Datetime.  Then set that to an index.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6])
scripps.Date=pd.to_datetime(scripps.Date)
scripps=scripps.set_index('Date')
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 1968-10-23 to 2014-12-17
# Data columns (total 3 columns):
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 38.9+ KB
# None

# %% [markdown]
# We could also do it all at once.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6])
scripps=scripps.set_index(pd.to_datetime(scripps.Date))
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 1968-10-23 to 2014-12-17
# Data columns (total 4 columns):
# Date     1244 non-null object
# Hr       1244 non-null object
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 48.6+ KB
# None

# %% [markdown]
# But back to reading in. We can also add the hours to the date and set the index and dateime all at once.  BUT YOU NEED the double brackets on parse dates for this to work.

# %%
scripps=pd.read_csv('fldav_ljo.csv',skiprows=68,usecols=[0,1,5,6],parse_dates=[['Date','Hr']]
                    ,index_col='Date_Hr')
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1244 entries, 1968-10-23 11:10:00 to 2014-12-17 17:25:00
# Data columns (total 2 columns):
# Flags    1244 non-null int64
# CO2      1244 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 29.2 KB
# None

# %% [markdown]
# This is a fun trick.  We can use python to grab the csv file for us off of the website!  No need to download.  But something is wrong with the file and we will lose the first row of data.  I needed to change to 69 skip rows and then you can see the problem with the names.

# %%
url='http://scrippsco2.ucsd.edu/sites/default/files/data/flask_co2_and_isotopic/daily_co2/fldav_ljo.csv'
scripps=pd.read_csv(url,skiprows=69,usecols=[0,1,5,6])
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1250 entries, 0 to 1249
# Data columns (total 4 columns):
# 1968-10-23    1250 non-null object
#  11:10        1250 non-null object
#   4           1250 non-null int64
#  369.38       1250 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 48.8+ KB
# None

# %% [markdown]
# Since the file is a little messed up we can set our datetime index first.

# %%
url='http://scrippsco2.ucsd.edu/sites/default/files/data/flask_co2_and_isotopic/daily_co2/fldav_ljo.csv'
scripps=pd.read_csv(url,skiprows=69,usecols=[0,1,5,6],parse_dates=[[0,1]],index_col=[0])
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1250 entries, 1968-10-31 14:44:00 to 2015-05-04 14:41:00
# Data columns (total 2 columns):
#   4        1250 non-null int64
#  369.38    1250 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 29.3 KB
# None

# %% [markdown]
# Now we can rename our columns and lose our first datapoint

# %%
url='http://scrippsco2.ucsd.edu/sites/default/files/data/flask_co2_and_isotopic/daily_co2/fldav_ljo.csv'
scripps=pd.read_csv(url,skiprows=69,usecols=[0,1,5,6],parse_dates=[[0,1]],index_col=[0])
scripps.columns=['Flags','CO2']
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1250 entries, 1968-10-31 14:44:00 to 2015-05-04 14:41:00
# Data columns (total 2 columns):
# Flags    1250 non-null int64
# CO2      1250 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 29.3 KB
# None

# %% [markdown]
# You are now an expert at getting data in.  You can figure it out!  Lets plot the date.

# %%
scripps.plot()

# %% [markdown]
# Lets just plot the CO2 data

# %%
scripps.CO2.plot()

# %% [markdown]
# There is obviosly some bad data points.  Go look at the csv file header and figure out which values are good and only keep the good data.  Good data has a flag of 0.  I am going to drop all the other data

# %%
scripps=scripps[scripps.Flags==0]
scripps.CO2.plot()

# %% [markdown]
# Now that is much nicer!

# %% [markdown]
# Now can you plot just the data from your birth year?

# %%
scripps['1972'].CO2.plot()

# %% [markdown]
# Remember all your slicing?  We can also now slice by Date!!!

# %% [markdown]
# Now just plot it for the years you were in high school

# %%
scripps['1987':'1990'].CO2.plot()

# %% [markdown]
# Now I am going to go complicated on you.  This is the first time I am trying it and I am not sure it will work.  Can we make a boxplot of CO2 for each year? I will make a new column that is the year and the I will make a boxplot by year.  Here is the documentation http://pandas-docs.github.io/pandas-docs-travis/visualization.html.  This is an important note.  To make a new column you have to use the [] notation and not the . notation.  See this example.

# %%
scripps['Year']=scripps.index.year
print scripps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1111 entries, 1969-01-13 15:00:00 to 2015-05-04 14:41:00
# Data columns (total 3 columns):
# Flags    1111 non-null int64
# CO2      1111 non-null float64
# Year     1111 non-null int32
# dtypes: float64(1), int32(1), int64(1)
# memory usage: 30.4 KB
# None

# %% [markdown]
# You can also make new columns by using math.  What if you wanted to make a new dataframe that was the CO2 times 10 minues 5?

# %%
df=pd.DataFrame()
df['CO2_10x']=scripps.CO2*10.0-5.0
print df.head()
# Out:
#                      CO2_10x
# 1968-10-23_ 11:10
# 1969-01-13 15:00:00   3325.0
# 1969-01-17 15:24:00   3310.0
# 1969-01-29 15:47:00   3300.0
# 1969-02-18 16:28:00   3260.0
# 1969-02-21 14:12:00   3260.8

# %% [markdown]
# Now remember back to boxplots...... Can you make a boxplot of CO2 by year?

# %% [markdown]
# Making really pretty boxplots in Pandas isn't always perfect.  Here are a few hints to use our fig and ax nomenclature.  Fixing the ticks is harder.  You have to add a new label for each tick and then blanks for the ones you don't want.  just some tricks to put in your back pocket.

# %%
ax=scripps.boxplot(column='CO2',by='Year')
fig=ax.figure
fig.set_size_inches(12,6)
ax.set_title('A much better title')
ax.set_xticklabels(['1970','','','','','','','','','2000'])
fig.suptitle('')#This has to go last.

# %% [markdown]
# the next thing you might need to do is to resample by a larger time frame like a year. so what is the yearly mean?  By resample we mean take all the data and find a subset of it.  I am now just looking at the annual mean and plotting it all in one fell swoop.  You need the np.mean b/c we are using an numpy function on our data.

# %%
scripps.CO2.resample('A',how=np.mean).plot()

# %% [markdown]
# Now here is how we do our fig,ax to make it look nice within pandas.

# %%
fig,ax=plt.subplots()
fig.set_size_inches(6,6)
scripps.CO2.resample('A',how=np.mean).plot(ax=ax)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Date')
ax.set_title('Mean Annual CO$_2$ Concentraions at the La Jolla Pier')

# %%
fig,ax=plt.subplots()
fig.set_size_inches(6,6)
x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)
ax.scatter(x,y)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Date')
ax.set_title('Mean Annual CO$_2$ Concentraions at the La Jolla Pier')

# %% [markdown]
# We could also plot all the data with scatter.

# %%
fig,ax=plt.subplots()
fig.set_size_inches(6,6)
x=scripps.CO2.index
y=scripps.CO2
ax.scatter(x,y)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Date')
ax.set_title('Mean Annual CO$_2$ Concentraions at the La Jolla Pier')

# %% [markdown]
# Now back to using Pandas.

# %% [markdown]
# Offset Aliases
#
# A number of string aliases are given to useful common time series frequencies. We will refer to these aliases as offset aliases (referred to as time rules prior to v0.8.0).
#
# Alias	Description
# B	business day frequency
#
# C	custom business day frequency (experimental)
#
# D	calendar day frequency
#
# W	weekly frequency
#
# M	month end frequency
#
# BM	business month end frequency
#
# CBM	custom business month end frequency
#
# MS	month start frequency
#
# BMS	business month start frequency
#
# CBMS	custom business month start frequency
#
# Q	quarter end frequency
#
# BQ	business quarter endfrequency
#
# QS	quarter start frequency
#
# BQS	business quarter start frequency
#
# A	year end frequency
#
# BA	business year end frequency
#
# AS	year start frequency
#
# BAS	business year start frequency
#
# H	hourly frequency
#
# T	minutely frequency
#
# S	secondly frequency
#
# L	milliseonds
#
# U	microseconds
#
# N	nanoseconds

# %%
print scripps.CO2.resample('Q',how=np.mean)  #THis just shows the quartely amounts!  
#If there is an NAN it won't let me plot straight away.  not sure why.
# Out:
# 1968-10-23_ 11:10
# 1969-03-31    329.616000
# 1969-06-30    326.810000
# 1969-09-30           NaN
# 1969-12-31    325.345000
# 1970-03-31           NaN
# 1970-06-30    328.822500
# 1970-09-30    322.270000
# 1970-12-31    327.490000
# 1971-03-31    330.218000
# 1971-06-30    330.335000
# 1971-09-30    326.400000
# 1971-12-31           NaN
# 1972-03-31    334.170000
# 1972-06-30    331.450000
# 1972-09-30    324.315000
# 1972-12-31    327.963333
# 1973-03-31    331.228000
# 1973-06-30    334.030000
# 1973-09-30    325.590000
# 1973-12-31    329.510000
# 1974-03-31    333.830000
# 1974-06-30    335.910000
# 1974-09-30    327.440000
# 1974-12-31    330.516667
# 1975-03-31    334.550000
# 1975-06-30    335.680000
# 1975-09-30    331.580000
# 1975-12-31    332.490000
# 1976-03-31    336.050000
# 1976-06-30    336.825000
#                  ...
# 2008-03-31    388.370000
# 2008-06-30    389.805000
# 2008-09-30    380.088000
# 2008-12-31    387.160000
# 2009-03-31    390.446000
# 2009-06-30    390.545000
# 2009-09-30    379.860000
# 2009-12-31    386.602000
# 2010-03-31    391.698000
# 2010-06-30    393.876250
# 2010-09-30    382.430000
# 2010-12-31    391.245000
# 2011-03-31    395.188000
# 2011-06-30    395.986000
# 2011-09-30    385.005000
# 2011-12-31    390.295000
# 2012-03-31    396.862000
# 2012-06-30    397.223333
# 2012-09-30    390.198333
# 2012-12-31    394.634286
# 2013-03-31    400.011667
# 2013-06-30    400.990000
# 2013-09-30    390.984000
# 2013-12-31    397.200000
# 2014-03-31    402.586667
# 2014-06-30    402.412500
# 2014-09-30    394.311429
# 2014-12-31    401.210000
# 2015-03-31    401.785000
# 2015-06-30    404.110000
# Freq: Q-DEC, Name: CO2, dtype: float64

# %% [markdown]
# For the how part you can use any numpy array function. I have not found a list.  So you can try many.

# %% [markdown]
# For now we will go back and use the annual mean values.  So use those functions for the next few graphs.

# %% [markdown]
# Now you should be able to set an x to year and a Y to average CO2 and see if there is a linear correlation.  What is the r2 and the p-value.  Make a nice graph.  Use annual mean values.

# %%
# Your code here!

# %% [markdown]
# the $r^2$ is great but the curve looks non-linear. By that I mean the error looks systematic and not random.  could we find the residuals and plot them?  So could we plot how far off the value is from the line for each year?  So the residual is the difference in y-space for each value for each year.  I added the zero line for reference byt using ax.axhline(y=0).  You can set a lot of properties with this.

# %%
# Your code here!

# %% [markdown]
# So linear ain't working!  So lets go back to poly1d and see how a second order equation fits the data!  Do you remember using poly1d and all of its cool tricks????
#
# If you are going to use textstr to make a string with the results of poly1d to show the equation it takes a trick or two.  I did it two ways.  First you could cast something to a string.  So you could do
#
# textstr='CO2='+str(poly1d(a))
#
# or you could do
#
# textstr='CO2={}'.format(poly1d(a))
#
# If you want to subscript the 2 you can do the dollar sign trick for an equation with an underscore.  I can't close the dollar signs as it will show the eqauation
# CO$_2$ so you would need to write CO\$_2\$

# %%
# Your code here!

# %% [markdown]
# Now that is a great fit!!!!!!  We can also look at the residuals for it.  Can you plot the residuals???

# %%
# Your code here!

# %% [markdown]
# Now make a prediction for CO2 for 2016-2050!  Can you extend the line to 2050?

# %%
# Your code here

# %% [markdown]
# ### Comments!!!

# %% [markdown]
# I have been really bad about adding comments to the code I write. I try to write in markdown but you also want to add comments so people can follow the code.  So lets take our last code and add comments to help us using the hastag!  you will thank yourself in a few months from now.  So comment your last code and I knwo yuo can do better than me!

# %%
#your code and comments here!

# %% [markdown]
# ### Answers

# %%
scripps.boxplot(column='CO2',by='Year')

# %%
fig,ax=plt.subplots()
props=dict(boxstyle='round',facecolor='white',alpha=0.5)

x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)
ax.scatter(x,y)

results=stats.linregress(x,y)
ax.plot(x,results[0]*x+results[1])
textstr='m={:>12.3f}\nb ={:>10.3f}\n$r^2$={:>12.3f}\np ={:>12.3f}'.format(results[0],results[1],results[2]**2,results[3])
ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Year')

# %%
fig,ax=plt.subplots()

x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)

results=stats.linregress(x,y)
ax.scatter(x,y-(results[0]*x+results[1]))
ax.set_ylabel('Residual')
ax.set_xlabel('Year')
ax.axhline(y=0)

# %%
fit_order=2

fig,ax=plt.subplots()
props=dict(boxstyle='round',facecolor='white',alpha=0.5)

x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)

x_fit=np.linspace(x.min(),x.max())  #I set the range using the data
a=np.polyfit(x,y,fit_order)  #I just copied from above to have in the same cell
polynominal=np.poly1d(a)
y_fit=polynominal(x_fit)

textstr='CO$_2$={}'.format(polynominal)
ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=8,verticalalignment='top',bbox=props)

ax.plot(x_fit,y_fit)
ax.scatter(x,y)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Year')

# %%
fit_order=2

fig,ax=plt.subplots()

x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)

x_fit=np.linspace(x.min(),x.max())  
a=np.polyfit(x,y,fit_order)  
polynominal=np.poly1d(a)

ax.scatter(x,y-polynominal(x))

ax.set_ylabel('Residual')
ax.set_xlabel('Year')
ax.axhline(y=0)

# %%
fit_order=2

fig,ax=plt.subplots()
props=dict(boxstyle='round',facecolor='white',alpha=0.5)

x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)

x_fit=np.linspace(1970,2050)  
a=np.polyfit(x,y,fit_order)  
polynominal=np.poly1d(a)
y_fit=polynominal(x_fit)

ax.plot(x_fit,y_fit)
ax.scatter(x,y)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Year')

textstr='CO$_2$={}'.format(np.poly1d(a))
ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=8,verticalalignment='top',bbox=props)

# %%
#get the x and y data from the larger data set for plotting and statistics.
x=scripps.CO2.resample('A',how=np.mean).index.year
y=scripps.CO2.resample('A',how=np.mean)

#i am going to fit the data using poly1d and use linspace to give us a bunch of points.
fit_order=2   #this is the order of the line.
x_fit=np.linspace(1970,2050)  
a=np.polyfit(x,y,fit_order)  
polynominal=np.poly1d(a)
y_fit=polynominal(x_fit)

#plot the data, the fit, label the axes and add the equation using a text box.
fig,ax=plt.subplots()
ax.plot(x_fit,y_fit)
ax.scatter(x,y)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Year')

props=dict(boxstyle='round',facecolor='white',alpha=0.5)
textstr='CO$_2$={}'.format(np.poly1d(a))
ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=8,verticalalignment='top',bbox=props)

# %%
url='http://scrippsco2.ucsd.edu/sites/default/files/data/flask_co2_and_isotopic/daily_co2/fldav_ljo.csv'
scripps=pd.read_csv(url,skiprows=69,usecols=[0,1,5,6],parse_dates=[[0,1]],index_col=[0])
scripps.columns=['Flags','CO2']
fig,ax=plt.subplots()
fig.set_size_inches(6,6)
ax.scatter(scripps.CO2.index,scripps.CO2)
scripps.CO2.plot(ax=ax)
ax.set_ylabel('CO$_2$ (ppm)')
ax.set_xlabel('Date')
ax.set_title('Mean Annual CO$_2$ Concentraions at the La Jolla Pier')

# %%
scripps.CO2.index
# Out:
# DatetimeIndex(['1968-10-31 14:44:00', '1969-01-13 15:00:00',
#                '1969-01-17 15:24:00', '1969-01-20 15:42:00',
#                '1969-01-29 15:47:00', '1969-02-18 16:28:00',
#                '1969-02-21 14:12:00', '1969-04-01 15:00:00',
#                '1969-06-18 15:11:00', '1969-10-02 14:37:00',
#                ...
#                '2014-11-14 14:28:00', '2014-12-13 15:43:00',
#                '2014-12-17 17:25:00', '2015-02-20 14:44:00',
#                '2015-02-26 16:25:00', '2015-03-19 17:43:00',
#                '2015-04-01 15:38:00', '2015-04-06 13:56:00',
#                '2015-04-14 14:34:00', '2015-05-04 14:41:00'],
#               dtype='datetime64[ns]', name=u'1968-10-23_ 11:10', length=1250, freq=None, tz=None)

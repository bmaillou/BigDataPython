# %% [markdown]
# for a longer project we are going to look at Christa's Senior Thesis data and see if we can help her do her analyses.  Christa is going to explain her data.  She thinks there should be a correlation between LAI and some other parameter.  There are many other columns.  Your mission if you choose..........  Is to make a file with LAI versus everything else.  This should be one pdf file.  Then you should look at the plots and results. I would recommended printing out the r2 values, sort them and make two more figures.  One with the top 4 graphs on one figure and then one with the top 6 graphs on one figure.  all graphs should have a text box from linregress that show the slope, intercept, r2 and p-value.  remember r2 is just the r-value squared.   The data is in excel this time!!!!  Plus I shortened the column names.  So we have two tasks to figure out. First you could learn how to use pandas read_excel. This is a nice function and very similar to read_csv.  Or you could convert your data to a CSV.  Also, I used a dictionary to give the variables really nice names for the graphs.  I have the dictionary online and now you know how to swap out names!  You have all the knowledge you need!  My answers are on courseworks. This is due next monday.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %%
#christa=pd.read_excel('Arctic_Shrub_Christa.xlsx','Raw Data')
christa=pd.read_excel('Species-Arsenic-Data.xlsx')

# %%
christa
# Out:
#        Well  hematiteppm          As  Depth (m)  P-k__Bacteria  \
# 0    BS01-5          NaN         NaN       1.52            NaN
# 1    BS03-0          NaN         NaN       3.04            NaN
# 2    BS04-6          NaN         NaN       4.57            NaN
# 3    BS06-0          NaN         NaN       6.09            NaN
# 4    BS07-6    33.121772   49.095143       7.62       0.206108
# 5   BS07-6a          NaN   49.095143       7.62       0.000000
# 6    BS10.0          NaN  235.788571      10.05            NaN
# 7    BS10-7          NaN  282.654000      10.66            NaN
# 8   BS10-7a          NaN  282.654000      10.66       0.013988
# 9    BS11-0     0.000183  301.428657      10.97       0.000000
# 10   BS12-2          NaN  358.974314      12.19            NaN
# 11   BS13-7     0.000020  430.670543      13.71       0.000000
# 12   BS14-0          NaN  445.292800      14.02       0.000000
# 13   BS15-5          NaN  440.598027      15.50            NaN
# ...

# %%
props=dict(boxstyle='round',facecolor='wheat',alpha=0.5)
pp = PdfPages('christa.pdf')
fig,ax=plt.subplots()
rsq={}
ind_var='hematiteppm'
df=christa
for dep_var in df:
    if df[dep_var].dtype==float and dep_var!=ind_var:
        ax.scatter(df[ind_var],df[dep_var])
        ax.set_xlabel(ind_var)
        #ax.set_ylabel(axis_names[dep_var])
        ax.set_ylabel(dep_var)
        ax.set_ylim([df[dep_var].min(),df[dep_var].max()])
        xy=df[[ind_var,dep_var]].dropna()
        x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
        results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
        ax.plot(x,x*results[0]+results[1])       
        textstr='m={:.3f}\nb={:.3f}\nr2={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
        ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
        print dep_var,results[2]
        rsq[dep_var]=results[2]**2
        pp.savefig()
        ax.cla()

pp.close()
r2=pd.DataFrame(rsq.items(),columns=['name','rsq'])
r2.sort(columns='rsq',ascending=0,inplace=True)
#elems=r2.name[0:6]

print r2
# Out:
# As -0.383098066308
# Depth (m) 0.0222432895339
# P-k__Bacteria -0.0903645754136
# P-k__Bacteria.1 -0.20496120274
# P-k__Bacteria.2 -0.168983216887
# P-k__Bacteria;p__Acidobacteria;c__Acidobacteria-5;o__;f__;g__;s__ -0.0803561150772
# P-k__Bacteria;p__Acidobacteria;c__Acidobacteria-6;o__iii1-15;f__;g__;s__ -0.0803561150772
# P-k__Bacteria;p__Acidobacteria;c__Acidobacteriia;o__Acidobacteriales 0.252199231939
# P-k__Bacteria;p__Acidobacteria;c__Acidobacteriia;o__Acidobacteriales;f__Koribacteraceae;g__;s__ -0.102346382574
# P-k__Bacteria;p__Acidobacteria;c__Acidobacteriia;o__Acidobacteriales;f__Koribacteraceae;g__;s__.1 -0.0803561150772
# P-k__Bacteria;p__Acidobacteria;c__[Chloracidobacteria];o__PK29;f__;g__;s__ 0.00716014519547
# P-k__Bacteria;p__Acidobacteria;c__[Chloracidobacteria];o__RB41;f__;g__;s__ -0.0923588076428
# P-k__Bacteria;p__Acidobacteria;c__[Chloracidobacteria];o__RB41;f__;g__;s__.1 -0.100176370306
# ...

# %%
print r2.iloc[0,0]
# Out:
# P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Oxalobacteraceae;g__;s__.5

# %%
elems=r2.name[0:4]
ind_var='hematiteppm'
df=christa

f, axTemp = plt.subplots(2,2)
props=dict(boxstyle='round',facecolor='white',alpha=0.5)
f.set_size_inches(10,10)
f.subplots_adjust(wspace=0.2)

for i,elem in enumerate(elems):
#for i,j in enumerate(ax):
    ax=axTemp[i%2][i/2]
    ax.scatter(df[ind_var],df[elem])
    ax.set_xlabel(ind_var)
    ax.set_ylabel(axis_names[elem])
    ax.set_xlim([-.1,df[ind_var].max()*1.1])
    
    xy=df[[ind_var,elem]].dropna()
    x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
    results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
    ax.plot(x,x*results[0]+results[1]) 
    
    textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
    ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
    ax.text(0.93,0.95,chr(i + ord('A')),transform=ax.transAxes,fontsize=14,verticalalignment='top')

plt.savefig('christa-4.png')

# %%
elems=r2.name[0:6]
ind_var='hematiteppm'
df=christa

f, axTemp = plt.subplots(2,3)
props=dict(boxstyle='round',facecolor='white',alpha=0.5)
f.set_size_inches(15,10)
f.subplots_adjust(wspace=0.3)

for i,elem in enumerate(elems):
    ax=axTemp[i%2][i/2]
    print i%2,i/2
    ax.scatter(df[ind_var],df[elem])
    ax.set_xlabel(ind_var)
    ax.set_ylabel(axis_names[elem])
    ax.set_xlim([-.1,df[ind_var].max()*1.1])
    
    xy=df[[ind_var,elem]].dropna()
    x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
    results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
    ax.plot(x,x*results[0]+results[1]) 
    
    textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
    ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
    ax.text(0.93,0.95,chr(i + ord('A')),transform=ax.transAxes,fontsize=14,verticalalignment='top')

plt.savefig('christa-6.png')
# Out:
# 0 0
# 1 0
# 0 1
# 1 1
# 0 2
# 1 2

# %%
print r2.iloc[5,0]
axis_names={
'P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Oxalobacteraceae.3':'Oxalobacteraceae (%)'
}
# Out:
# P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales;f__Sphingomonadaceae;g__Sphingomonas;s__

# %%
print r2.iloc[1,0]
axis_names={
'P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Oxalobacteraceae.3':'Oxalobacteraceae (%)',
'P-k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales.1':'Clostridiales.1(%)',
'P-k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae;g__SMB53;s__':'Clostridiaceae;g__SMB53 (%)',    
'P-k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Peptostreptococcaceae;g__;s__':'Peptostreptococcaceae (%)',
'P-k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae;g__SMB53;s__.2':'Clostridiaceae;g__SMB53 (%)',
'P-k__Bacteria;p__Firmicutes;c__Clostridia;o__Clostridiales;f__Clostridiaceae;g__SMB53;s__.1':'Clostridiaceae;g__SMB53;s__.1 (%)',
'P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Rhizobiaceae':'Rhizobiaceae (%)',
'P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Oxalobacteraceae;g__;s__.5':'Oxalobacteraceae;g__;s__.5(%)',
'P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales;f__Sphingomonadaceae;g__Kaistobacter;s__.1':'Kaistobacter;s__.1(%)',    
'P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Oxalobacteraceae.8':'Oxalobacteraceae.8(%)',
'P-k__Bacteria;p__Proteobacteria;c__Betaproteobacteria;o__Burkholderiales;f__Comamonadaceae;g__Comamonas;s__.1':'Comamonas;s__.1(%)',   
'P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Caulobacterales;f__Caulobacteraceae;g__Mycoplana;s__':'Mycoplana;s__(%)',
'P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales;f__Sphingomonadaceae;g__Sphingomonas;s__':'Sphingomonas;s__(%)',
}
# Out:
# P-k__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Sphingomonadales;f__Sphingomonadaceae;g__Kaistobacter;s__.1

# %%
axis_names={
'Sample':'Sample',
'Species':'Species',
'SizeClass':'Size Class',
'LeafPos':'Leaf Position',
'Conditions':'Conditions',
'LAI':'LAI',
'ChlB':'Chlorophyll B Concentration ($\mu$mol/m$^2$)',
'ChlA':'Chlorophyll A Concentration ($\mu$mol/m$^2$)',
'ChlP':'Chlorophyll Pool ($\mu$mol/m$^2$)',
'chlAB':'Chlorophylla/b Ratio',
'Viol':'Violaxanthin Concentration ($\mu$mol/m$^2$)',
'Neox':'Neoxanthin Concentration ($\mu$mol/m$^2$)',
'Anth':'Antheraxanthin Concentration($\mu$mol/m$^2$)',
'Lutein':'Lutein Concentration ($\mu$mol/m$^2$)',
'Zeax':'Zeaxanthin Concentration ($\mu$mol/m$^2$)',
'Beta':'Beta Carotene Concentration ($\mu$mol/m$^2$)',
'VAZ':'V+A+Z ($\mu$mol/m$^2$)',
'VAZC':'V+A+Z /ChlA+ChlB (mmol/mol)',
'ZVAZ':'Z/V+A+Z',
'ZAVAZ':'Z+A/V+A+Z',
'O':'O',
'T100':'T100',
'K':'K',
'J':'J',
'I':'I',
'P':'P',
'S':'S',
'M':'M',
'T':'T',
'tFm':'tFm',
'Fo':'Fo',
'Fm':'Fm',
'FvFm':'Fv/Fm',
'FvFo':'Fv/Fo',
'Vj':'Vj',
'Pl':'PI',
'Mo':'Mo',
'ABSRC':'ABS/RC',
'TRoRC':'TRo/RC',
'DIoCS':'DIo/CS',
'EToRC':'ETo/RC',
'TRoABS':'TRo/ABS',
'EToTRo':'ETo/TRo',
'EToCS':'ETo/CS',
'RCCSo':'RC/CSo',
'RCCSm':'RC/CSm',
'Area':'Area',
}

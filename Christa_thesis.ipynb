# %% [markdown]
# for a longer project we are going to look at Christa's Senior Thesis data and see if we can help her do her analyses.  Christa is going to explain her data.  She thinks there should be a correlation between LAI and some other parameter.  There are many other columns.  Your mission if you choose..........  Is to make a file with LAI versus everything else.  This should be one pdf file.  Then you should look at the plots and results. I would recommended printing out the r2 values, sort them and make two more figures.  One with the top 4 graphs on one figure and then one with the top 6 graphs on one figure.  all graphs should have a text box from linregress that show the slope, intercept, r2 and p-value.  remember r2 is just the r-value squared.   The data is in excel this time!!!!  Plus I shortened the column names.  So we have two tasks to figure out. First you could learn how to use pandas read_excel. This is a nice function and very similar to read_csv.  Or you could convert your data to a CSV.  Also, I used a dictionary to give the variables really nice names for the graphs.  I have the dictionary online and now you know how to swap out names!  You have all the knowledge you need!  My answers are on courseworks. This is due next monday.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
from matplotlib.backends.backend_pdf import PdfPages

# %%
christa=pd.read_excel('Arctic_Shrub_Christa.xlsx','Raw Data')

# %%
christa
# Out:
#     Sample        Species    SizeClass LeafPos Conditions   LAI        ChlB  \
# 0     PS1A  Salix pulchra        small       A       dark  0.07  114.524123
# 1     PS1A  Salix pulchra        small       A      light  0.07  114.994671
# 2     PS1B  Salix pulchra        small       B       dark  0.25         NaN
# 3     PS1B  Salix pulchra        small       B      light  0.25         NaN
# 4     PS1C  Salix pulchra        small       C       dark  0.00         NaN
# 5     PS1C  Salix pulchra        small       C      light  0.00         NaN
# 6     PS1D  Salix pulchra        small       D       dark  0.00  106.274838
# 7     PS1D  Salix pulchra        small       D      light  0.00   99.812148
# 8     PS1E  Salix pulchra        small       E       dark  0.16   88.058005
# 9     PS1E  Salix pulchra        small       E      light  0.16   93.947520
# 10    PS1F  Salix pulchra        small       F       dark  0.11         NaN
# 11    PS1F  Salix pulchra        small       F      light  0.11         NaN
# 12    PS1G  Salix pulchra        small       G       dark  0.63         NaN
# 13    PS1G  Salix pulchra        small       G      light  0.63         NaN
# 14    PS1H  Salix pulchra        small       H       dark  0.36         NaN
# 15    PS1H  Salix pulchra        small       H      light  0.36         NaN
# 16    PS1I  Salix pulchra        small       I       dark  0.56         NaN
# 17    PS1I  Salix pulchra        small       I      light  0.56         NaN
# 18    PS1J  Salix pulchra        small       J       dark  0.90         NaN
# 19    PS1J  Salix pulchra        small       J      light  0.90         NaN
# 20    PS2A  Salix pulchra        small       A       dark  0.00         NaN
# 21    PS2A  Salix pulchra        small       A      light  0.00         NaN
# 22    PS2B  Salix pulchra        small       B       dark  0.00   74.019469
# 23    PS2B  Salix pulchra        small       B      light  0.00   75.291150
# 24    PS2C  Salix pulchra        small       C       dark  0.00         NaN
# 25    PS2C  Salix pulchra        small       C      light  0.00         NaN
# 26    PS2D  Salix pulchra        small       D       dark  0.26         NaN
# 27    PS2D  Salix pulchra        small       D      light  0.26         NaN
# 28    PS2E  Salix pulchra        small       E       dark  0.25         NaN
# 29    PS2E  Salix pulchra        small       E      light  0.25         NaN
# ..     ...            ...          ...     ...        ...   ...         ...
# 370   BL3F    Betula nana        large       F       dark  0.39         NaN
# 371   BL3F    Betula nana        large       F      light  0.39         NaN
# 372   BL3G    Betula nana        large       G       dark  0.81  146.082858
# 373   BL3G    Betula nana        large       G      light  0.81   76.466623
# 374   BL3H    Betula nana        large       H       dark  1.18         NaN
# 375   BL3H    Betula nana        large       H      light  1.18         NaN
# 376   BL3I    Betula nana        large       I       dark  1.27  178.656184
# 377   BL3I    Betula nana        large       I      light  1.27  164.525451
# 378   BL3J    Betula nana        large       J       dark  1.72  128.878609
# 379   BL3J    Betula nana        large       J      light  1.72  143.389718
# 380  BXL1A    Betula nana  extra large       A       dark  0.00   90.145345
# 381  BXL1A    Betula nana  extra large       A      light  0.00   85.987107
# 382  BXL1B    Betula nana  extra large       B       dark  0.00         NaN
# 383  BXL1B    Betula nana  extra large       B      light  0.00         NaN
# 384  BXL1C    Betula nana  extra large       C       dark  0.11         NaN
# 385  BXL1C    Betula nana  extra large       C      light  0.11         NaN
# 386  BXL1D    Betula nana  extra large       D       dark  0.28  119.524127
# 387  BXL1D    Betula nana  extra large       D      light  0.28  103.171920
# 388  BXL1E    Betula nana  extra large       E       dark  0.29   82.952774
# 389  BXL1E    Betula nana  extra large       E      light  0.29   88.434972
# 390  BXL1F    Betula nana  extra large       F       dark  0.77         NaN
# 391  BXL1F    Betula nana  extra large       F      light  0.77         NaN
# 392  BXL1G    Betula nana  extra large       G       dark  0.84  117.447455
# 393  BXL1G    Betula nana  extra large       G      light  0.84  113.750956
# 394  BXL1H    Betula nana  extra large       H       dark  1.92         NaN
# 395  BXL1H    Betula nana  extra large       H      light  1.92         NaN
# 396  BXL1I    Betula nana  extra large       I       dark  1.47         NaN
# 397  BXL1I    Betula nana  extra large       I      light  1.47         NaN
# 398  BXL1J    Betula nana  extra large       J       dark  1.62  101.758780
# 399  BXL1J    Betula nana  extra large       J      light  1.62  123.308981
#
#            ChlA        ChlP     chlAB  ...     ABSRC   TRoRC   DIoCS   EToRC  \
# 0    335.170462  449.694585  2.926636  ...     1.966  0.3135  0.6487  0.8038
# 1    341.899658  456.894329  2.973178  ...     3.385  0.2341  2.4103  0.5853
# 2           NaN         NaN       NaN  ...     2.645  0.3496  1.1441  0.9475
# 3           NaN         NaN       NaN  ...    11.279  0.7238  8.3749  1.5327
# 4           NaN         NaN       NaN  ...     1.493  0.2361  0.5484  0.4636
# 5           NaN         NaN       NaN  ...    -2.996 -0.1828 -2.2349 -0.3047
# 6    295.453565  401.728403  2.780090  ...     2.128  0.3286  0.8014  0.5997
# 7    279.781462  379.593610  2.803080  ...    -0.937 -0.0675 -0.6369 -0.1978
# 8    230.012602  318.070607  2.612058  ...     1.695  0.3076  0.4591  0.6610
# 9    261.730383  355.677904  2.785921  ...     3.134  0.2953  1.9194  0.7088
# 10          NaN         NaN       NaN  ...     1.931  0.2439  0.6780  0.9214
# 11          NaN         NaN       NaN  ...     5.061  0.3118  3.6924  0.4804
# 12          NaN         NaN       NaN  ...     2.345  0.3703  0.8631  0.7249
# 13          NaN         NaN       NaN  ...     6.971  0.3980  4.9537  1.4727
# 14          NaN         NaN       NaN  ...     1.756  0.2823  0.5907  0.6857
# 15          NaN         NaN       NaN  ...     3.753  0.2780  2.6361  0.5212
# 16          NaN         NaN       NaN  ...     1.882  0.3163  0.5854  0.7491
# 17          NaN         NaN       NaN  ...     3.651  0.3147  2.3397  0.5245
# 18          NaN         NaN       NaN  ...     1.680  0.2643  0.5946  0.6315
# 19          NaN         NaN       NaN  ...     5.224  0.4121  3.4577  1.1127
# 20          NaN         NaN       NaN  ...     2.080  0.3397  0.6276  0.9110
# 21          NaN         NaN       NaN  ...     4.892  0.5096  2.8524  1.0510
# 22   197.674309  271.693778  2.670572  ...     1.546  0.2818  0.3772  0.6950
# 23   233.751345  309.042495  3.104632  ...     1.423  0.1456  0.8101  0.3751
# 24          NaN         NaN       NaN  ...     2.115  0.3545  0.6969  0.6936
# 25          NaN         NaN       NaN  ...     1.887  0.1713  1.1815  0.4131
# 26          NaN         NaN       NaN  ...     1.594  0.2529  0.3747  0.8617
# 27          NaN         NaN       NaN  ...     2.775  0.3226  1.4826  0.6205
# 28          NaN         NaN       NaN  ...     1.301  0.2151  0.2376  0.7649
# 29          NaN         NaN       NaN  ...     2.852  0.3916  1.2827  0.8181
# ..          ...         ...       ...  ...       ...     ...     ...     ...
# 370         NaN         NaN       NaN  ...     1.727  0.2575  0.5286  0.8248
# 371         NaN         NaN       NaN  ...     3.256  0.3929  1.6837  0.8063
# 372  454.730946  600.813804  3.112829  ...     1.915  0.3228  0.5535  0.8350
# 373  223.478661  299.945283  2.922565  ...     2.209  0.2012  1.3311  0.5654
# 374         NaN         NaN       NaN  ...     2.058  0.3424  0.6810  0.6380
# 375         NaN         NaN       NaN  ...     2.540  0.2922  1.3690  0.5609
# 376  524.799591  703.455775  2.937483  ...     1.513  0.2640  0.3118  0.8095
# 377  544.271890  708.797340  3.308132  ...     1.928  0.2463  0.9221  0.4311
# 378  335.174569  464.053178  2.600700  ...     1.700  0.3119  0.3250  0.8966
# 379  386.796374  530.186092  2.697518  ...     2.076  0.2899  0.9160  0.5828
# 380  267.156234  357.301579  2.963617  ...     2.142  0.2634  1.0712  0.4674
# 381  243.087122  329.074229  2.827018  ...     4.709  0.5079  2.6502  0.9108
# 382         NaN         NaN       NaN  ...     2.216  0.3326  0.8648  0.5916
# 383         NaN         NaN       NaN  ...     1.738  0.2047  0.9118  0.4525
# 384         NaN         NaN       NaN  ...     2.159  0.3348  0.8150  0.6293
# 385         NaN         NaN       NaN  ...     2.137  0.2744  1.0388  0.5381
# 386  325.864918  445.389045  2.726353  ...     2.030  0.3145  0.7181  0.5231
# 387  291.363213  394.535133  2.824055  ...     1.411  0.1729  0.7146  0.3798
# 388  218.542158  301.494932  2.634537  ...     1.917  0.2537  0.8613  0.4241
# 389  249.069561  337.504533  2.816415  ...     1.785  0.1957  0.9968  0.4289
# 390         NaN         NaN       NaN  ...     1.764  0.2848  0.6169  0.5259
# 391         NaN         NaN       NaN  ...     1.995  0.2716  0.8963  0.6078
# 392  299.800287  417.247743  2.552633  ...     1.897  0.3292  0.4718  0.9099
# 393  312.978913  426.729870  2.751440  ...     2.201  0.3100  0.9541  0.6708
# 394         NaN         NaN       NaN  ...     1.942  0.3310  0.6108  0.7154
# 395         NaN         NaN       NaN  ...     3.229  0.3499  1.7330  0.9381
# 396         NaN         NaN       NaN  ...     2.259  0.2382  0.9825  0.3170
# 397         NaN         NaN       NaN  ...     3.421  0.3153  1.9795  0.9757
# 398  279.194185  380.952965  2.743686  ...     2.053  0.3145  0.7920  0.6606
# 399  335.188842  458.497823  2.718284  ...     3.420  0.4426  1.6422  0.9478
#
#      TRoABS  EToTRo    EToCS    RCCSo    RCCSm   Area
# 0     0.670  0.6099   77.657   96.612  292.888  10250
# 1     0.288  0.6000   21.783   37.212   52.275   1383
# 2     0.567  0.6309   51.567   54.423  125.853  12405
# 3     0.257  0.5277   16.850   10.993   14.806   2370
# 4     0.632  0.4907   62.717  135.272  368.314   7407
# 5     0.254  0.4000   13.423  -44.046  -59.062   1097
# 6     0.623  0.4519   60.582  101.011  268.266   9849
# 7     0.320  0.6585   25.955 -131.221 -193.097   1536
# 8     0.729  0.5346   78.759  119.135  439.975  31830
# 9     0.387  0.5833   31.433   44.343   72.416   1983
# 10    0.648  0.7352   53.439   57.997  165.188  16509
# 11    0.270  0.3508   14.333   29.831   40.894   2088
# 12    0.631  0.4891   77.592  107.027  290.808  10413
# 13    0.289  0.7297   28.517   19.363   27.252   1838
# 14    0.663  0.5882   73.003  106.463  316.544   9713
# 15    0.297  0.4666   16.388   31.439   44.761   1468
# 16    0.688  0.5777   79.612  106.265  341.642   9922
# 17    0.359  0.4000   22.556   42.998   67.100   1305
# 18    0.646  0.5814   62.749   99.360  280.825  10405
# 19    0.338  0.6296   28.750   25.837   39.043   1518
# 20    0.698  0.6270   70.932   77.861  258.096   8569
# 21    0.417  0.5151   30.934   29.430   50.482   2465
# 22    0.756  0.5944   81.353  117.042  479.811  11756
# 23    0.430  0.6117   37.953  101.160  177.734   2606
# 24    0.670  0.4888   73.110  105.395  319.967   9051
# 25    0.373  0.5853   33.713   81.590  130.333   2855
# 26    0.765  0.7064  101.600  117.901  501.707  15792
# 27    0.465  0.4800   36.667   59.088  110.610   2417
# 28    0.817  0.7187  104.587  136.715  748.864  18110
# 29    0.550  0.5212   46.176   56.443  125.508   3169
# ..      ...     ...      ...      ...      ...    ...
# 370   0.694  0.6877   63.965   77.548  253.479   8464
# 371   0.482  0.5126   37.632   46.672   90.274   1629
# 372   0.710  0.6134   42.735   51.174  177.023   4470
# 373   0.397  0.6440   36.092   63.826  105.925   1027
# 374   0.669  0.4632   69.435  108.822  328.895   6514
# 375   0.461  0.4789   36.658   65.349  121.250   2061
# 376   0.793  0.6737  116.620  144.058  699.146  14438
# 377   0.521  0.4285   44.273  102.689  214.714   2050
# 378   0.808  0.6520  109.698  122.348  639.976  13447
# 379   0.558  0.5024   55.873   95.855  217.241   1616
# 380   0.500  0.4363   13.745   29.405   58.811   2109
# 381   0.437  0.4423   30.365   33.335   59.240   2443
# 382   0.609  0.4376   72.067  121.803  312.178   8876
# 383   0.475  0.5474   47.376  104.690  199.602   2330
# 384   0.622  0.4680   58.279   92.598  245.385   6842
# 385   0.513  0.4900   44.071   81.890  168.460   1987
# 386   0.646  0.3986   28.341   54.177  153.173   7777
# 387   0.493  0.5447   44.387  116.865  230.897   2650
# 388   0.550  0.4017   50.000  117.890  262.383   7914
# 389   0.441  0.5436   39.151   91.275  163.511   2499
# 390   0.650  0.4584   74.231  141.147  403.603  10265
# 391   0.550  0.5530   51.178   84.189  187.422   2557
# 392   0.751  0.6382   88.709   97.490  392.071  10491
# 393   0.566  0.5377   62.464   93.115  214.846   2316
# 394   0.685  0.5372   88.027  123.035  391.243   9685
# 395   0.463  0.6269   53.163   56.668  105.594   2213
# 396   0.565  0.2483   50.663  159.801  367.411   7685
# 397   0.421  0.6767   49.338   50.565   87.393   2806
# 398   0.614  0.5238   99.417  150.491  390.107  11414
# 399   0.519  0.5329   56.804   59.928  124.826   2384
#
# [400 rows x 47 columns]

# %%
props=dict(boxstyle='round',facecolor='wheat',alpha=0.5)
pp = PdfPages('christa.pdf')
fig,ax=plt.subplots()
rsq={}
ind_var='LAI'
df=christa
for dep_var in df:
    if df[dep_var].dtype==float and dep_var!=ind_var:
        ax.scatter(df[ind_var],df[dep_var])
        ax.set_xlabel(ind_var)
        ax.set_ylabel(axis_names[dep_var])
        ax.set_ylim([df[dep_var].min(),df[dep_var].max()])
        xy=df[[ind_var,dep_var]].dropna()
        x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
        results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
        ax.plot(x,x*results[0]+results[1])       
        textstr='m={:.3f}\nb={:.3f}\nr2={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
        ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)
        print dep_var,results[2]
        rsq[dep_var]=results[2]**2
        pp.savefig()
        ax.cla()

pp.close()
r2=pd.DataFrame(rsq.items(),columns=['name','rsq'])
r2.sort(columns='rsq',ascending=0,inplace=True)
#elems=r2.name[0:6]

print r2
# Out:
# ChlB 0.120738266671
# ChlA 0.0192769863976
# ChlP 0.0437135002516
# chlAB -0.205386367032
# Viol -0.125648485734
# Neox -0.148668454491
# Anth -0.34198476112
# Lutein -0.193269641567
# Zeax -0.206303730094
# Beta 0.120478455233
# VAZ -0.294827913658
# VAZC -0.221892865745
# ZVAZ -0.137031781581
# ZAVAZ -0.161809232368
# FvFm 0.0991860590879
# FvFo 0.136783175504
# Vj -0.0967233215972
# Pl 0.161338054251
# Mo -0.0391325770731
# ABSRC -0.01347734114
# TRoRC -0.017539484322
# DIoCS -0.0163015597818
# EToRC 0.0336197188508
# TRoABS 0.0991860590879
# EToTRo 0.0967179754198
# EToCS 0.209437565992
# RCCSo 0.117208449458
# RCCSm 0.188080444112
#       name       rsq
# 23    Anth  0.116954
# 19     VAZ  0.086923
# 26    VAZC  0.049236
# 25   EToCS  0.043864
# 20    Zeax  0.042561
# 21   chlAB  0.042184
# 16  Lutein  0.037353
# 14   RCCSm  0.035374
# 1    ZAVAZ  0.026182
# 4       Pl  0.026030
# 24    Neox  0.022102
# 17    ZVAZ  0.018778
# 2     FvFo  0.018710
# 7     Viol  0.015788
# 9     ChlB  0.014578
# 12    Beta  0.014515
# 15   RCCSo  0.013738
# 0   TRoABS  0.009838
# 3     FvFm  0.009838
# 22      Vj  0.009355
# 6   EToTRo  0.009354
# 13    ChlP  0.001911
# 18      Mo  0.001531
# 10   EToRC  0.001130
# 8     ChlA  0.000372
# 11   TRoRC  0.000308
# 27   DIoCS  0.000266
# 5    ABSRC  0.000182

# %%
elems=r2.name[0:4]
ind_var='LAI'
df=christa

f, axTemp = plt.subplots(2,2)
props=dict(boxstyle='round',facecolor='white',alpha=0.5)
f.set_size_inches(10,10)
f.subplots_adjust(wspace=0.2)

for i,elem in enumerate(elems):
#for i,j in enumerate(ax):
    ax=axTemp[i%2][i/2]
    print i%2,i/2
    ax.scatter(df[ind_var],df[elem])
    ax.set_xlabel(ind_var)
    ax.set_ylabel(axis_names[elem])
    ax.set_xlim([-.1,df[ind_var].max()*1.1])
    
    xy=df[[ind_var,elem]].dropna()
    x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
    results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
    ax.plot(x,x*results[0]+results[1]) 
    
    textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
    ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)

plt.savefig('christa-4.png')
# Out:
# 0 0
# 1 0
# 0 1
# 1 1

# %%
elems=r2.name[0:6]
ind_var='LAI'
df=christa

f, axTemp = plt.subplots(2,3)
props=dict(boxstyle='round',facecolor='white',alpha=0.5)
f.set_size_inches(15,10)
f.subplots_adjust(wspace=0.3)

for i,elem in enumerate(elems):
    ax=axTemp[i%2][i/2]
    print i%2,i/2
    ax.scatter(df[ind_var],df[elem])
    ax.set_xlabel(ind_var)
    ax.set_ylabel(axis_names[elem])
    ax.set_xlim([-.1,df[ind_var].max()*1.1])
    
    xy=df[[ind_var,elem]].dropna()
    x=np.array([xy.iloc[:,0].min(),xy.iloc[:,0].max()])        
    results=stats.linregress(xy.iloc[:,0],xy.iloc[:,1])
    ax.plot(x,x*results[0]+results[1]) 
    
    textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3f}'.format(results[0],results[1],results[2]**2,results[3])
    ax.text(0.05,0.95,textstr,transform=ax.transAxes,fontsize=10,verticalalignment='top',bbox=props)

plt.savefig('christa-6.png')
# Out:
# 0 0
# 1 0
# 0 1
# 1 1
# 0 2
# 1 2

# %%
axis_names={
'Sample':'Sample',
'Species':'Species',
'SizeClass':'Size Class',
'LeafPos':'Leaf Position',
'Conditions':'Conditions',
'LAI':'LAI',
'ChlB':'Chlorophyll B Concentration ($\mu$mol/m$^2$)',
'ChlA':'Chlorophyll A Concentration ($\mu$mol/m$^2$)',
'ChlP':'Chlorophyll Pool ($\mu$mol/m$^2$)',
'chlAB':'Chlorophylla/b Ratio',
'Viol':'Violaxanthin Concentration ($\mu$mol/m$^2$)',
'Neox':'Neoxanthin Concentration ($\mu$mol/m$^2$)',
'Anth':'Antheraxanthin Concentration($\mu$mol/m$^2$)',
'Lutein':'Lutein Concentration ($\mu$mol/m$^2$)',
'Zeax':'Zeaxanthin Concentration ($\mu$mol/m$^2$)',
'Beta':'Beta Carotene Concentration ($\mu$mol/m$^2$)',
'VAZ':'V+A+Z ($\mu$mol/m$^2$)',
'VAZC':'V+A+Z /ChlA+ChlB (mmol/mol)',
'ZVAZ':'Z/V+A+Z',
'ZAVAZ':'Z+A/V+A+Z',
'O':'O',
'T100':'T100',
'K':'K',
'J':'J',
'I':'I',
'P':'P',
'S':'S',
'M':'M',
'T':'T',
'tFm':'tFm',
'Fo':'Fo',
'Fm':'Fm',
'FvFm':'Fv/Fm',
'FvFo':'Fv/Fo',
'Vj':'Vj',
'Pl':'PI',
'Mo':'Mo',
'ABSRC':'ABS/RC',
'TRoRC':'TRo/RC',
'DIoCS':'DIo/CS',
'EToRC':'ETo/RC',
'TRoABS':'TRo/ABS',
'EToTRo':'ETo/TRo',
'EToCS':'ETo/CS',
'RCCSo':'RC/CSo',
'RCCSm':'RC/CSm',
'Area':'Area',
}
